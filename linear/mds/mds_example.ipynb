# %% [markdown]
# ### Example of PCA: Application to Iris dataset (cp. [scikit-learn](https://scikit-learn.org/stable/auto_examples/decomposition/plot_pca_iris.html))

# %%
# Imports
from sklearn.manifold import MDS

from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler

# %run mds.ipynb # own implementation

# %%
# Load dataset and save variables
digits = load_digits(n_class=3)
X, y = digits.data, digits.target

# %% [markdown]
# #### My implementation

# %%
# Define parameters
dim = 2
typ = 'k'
# Call MDS method
Y = get_mds(X, dim, typ='Classical')

# %%
# Plot MDS embedding
plot_embedding(Y.T, "My MDS embedding")

# %% [markdown]
# #### Sklearn's implementation

# %%
# Define parameters
n_neighbors = 30
dim = 2
# Call MDS method
embedding = MDS(n_components=dim, metric=True, dissimilarity='euclidean')
Y_sklearn = embedding.fit_transform(X)

# %%
# Plot ISOMAP embedding
plot_embedding(Y_sklearn, "Sklearn's MDS embedding")
